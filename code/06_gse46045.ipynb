# %% [markdown]
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE46045

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

import kraft

# %%
SETTING = kraft.json.read("setting.json")

# %%
gse_id = "GSE46045"

# %%
_x_samples = kraft.geo.get_gse(
    gse_id, SETTING["data_directory_path"], overwrite=SETTING["overwrite"]
)
